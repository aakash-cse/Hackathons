# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')

# %%
train.head()
# Out:
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0             9.0             286.0         0.552727               1.0
# 1            10.0              96.0         0.702128               1.0
# 2             9.0             399.0         0.675532               1.0
# 3            11.0            1388.0         0.482156               1.0
# 4            12.0             499.0         0.564682               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  num_videos  \
# 0                  0.612903        6.0             4.0       2.0         1.0
# 1                  0.796875        4.0             3.0      10.0         1.0
# 2                  0.813433       21.0             1.0      20.0         0.0
# 3                  0.685446       40.0             4.0       2.0         5.0
# 4                  0.752508       10.0             0.0       1.0         0.0
#
#    average_token_length  ...  min_positive_polarity  max_positive_polarity  \
# 0              4.702797  ...               0.136364                    1.0
# 1              4.458333  ...               0.200000                    0.5
# 2              4.859649  ...               0.100000                    0.6
# 3              4.562680  ...               0.033333                    1.0
# 4              4.961924  ...               0.100000                    0.6
#
#    avg_negative_polarity  min_negative_polarity  max_negative_polarity  \
# 0               0.000000                    0.0                   0.00
# 1              -0.650000                   -0.7                  -0.60
# 2              -0.180208                   -0.4                  -0.10
# 3              -0.260965                   -0.5                  -0.05
# 4              -0.195238                   -0.4                  -0.10
#
#    title_subjectivity  title_sentiment_polarity  abs_title_subjectivity  \
# 0            0.000000                  0.000000                0.500000
# 1            1.000000                  0.500000                0.500000
# 2            0.535714                  0.285714                0.035714
# 3            1.000000                 -0.500000                0.500000
# 4            0.650000                  0.350000                0.150000
#
#    abs_title_sentiment_polarity  shares
# 0                      0.000000  4751.0
# 1                      0.500000  1821.0
# 2                      0.285714  1420.0
# 3                      0.500000    52.0
# 4                      0.350000  4182.0
#
# [5 rows x 59 columns]

# %%
train.isnull().sum()
# Out:
# n_tokens_title                   0
# n_tokens_content                 0
# n_unique_tokens                  0
# n_non_stop_words                 0
# n_non_stop_unique_tokens         0
# num_hrefs                        0
# num_self_hrefs                   0
# num_imgs                         0
# num_videos                       0
# average_token_length             0
# num_keywords                     0
# data_channel_is_lifestyle        0
# data_channel_is_entertainment    0
# data_channel_is_bus              0
# data_channel_is_socmed           0
# data_channel_is_tech             0
# data_channel_is_world            0
# kw_min_min                       0
# kw_max_min                       0
# kw_avg_min                       0
# kw_min_max                       0
# kw_max_max                       0
# kw_avg_max                       0
# kw_min_avg                       0
# kw_max_avg                       0
# kw_avg_avg                       0
# self_reference_min_shares        0
# self_reference_max_shares        0
# self_reference_avg_sharess       0
# weekday_is_monday                0
# weekday_is_tuesday               0
# weekday_is_wednesday             0
# weekday_is_thursday              0
# weekday_is_friday                0
# weekday_is_saturday              0
# weekday_is_sunday                0
# is_weekend                       0
# LDA_00                           0
# LDA_01                           0
# LDA_02                           0
# LDA_03                           0
# LDA_04                           0
# global_subjectivity              0
# global_sentiment_polarity        0
# global_rate_positive_words       0
# global_rate_negative_words       0
# rate_positive_words              0
# rate_negative_words              0
# avg_positive_polarity            0
# min_positive_polarity            0
# max_positive_polarity            0
# avg_negative_polarity            0
# min_negative_polarity            0
# max_negative_polarity            0
# title_subjectivity               0
# title_sentiment_polarity         0
# abs_title_subjectivity           0
# abs_title_sentiment_polarity     0
# shares                           0
# dtype: int64

# %%
co = train.corr()
co
# Out:
#                                n_tokens_title  n_tokens_content  \
# n_tokens_title                       1.000000         -0.011682
# n_tokens_content                    -0.011682          1.000000
# n_unique_tokens                     -0.038403         -0.406451
# n_non_stop_words                    -0.043665          0.204110
# n_non_stop_unique_tokens            -0.042015         -0.227762
# num_hrefs                           -0.065715          0.444034
# num_self_hrefs                      -0.025405          0.321827
# num_imgs                            -0.009692          0.331687
# num_videos                           0.044753          0.111323
# average_token_length                -0.068069          0.174439
# num_keywords                        -0.010982          0.074837
# data_channel_is_lifestyle           -0.070038          0.032263
# data_channel_is_entertainment        0.118818          0.060450
# data_channel_is_bus                 -0.029200          0.010825
# data_channel_is_socmed              -0.085983          0.026505
# data_channel_is_tech                -0.043363          0.019907
# data_channel_is_world                0.049007          0.048090
# kw_min_min                          -0.102370         -0.052591
# kw_max_min                          -0.016050          0.006954
# kw_avg_min                          -0.037999         -0.000358
# kw_min_max                           0.018715         -0.020196
# kw_max_max                           0.105716          0.064802
# kw_avg_max                           0.123020         -0.093373
# kw_min_avg                           0.003871         -0.021324
# kw_max_avg                          -0.020725         -0.033505
# kw_avg_avg                          -0.010700         -0.079329
# self_reference_min_shares            0.000507         -0.029184
# self_reference_max_shares            0.004770          0.029983
# self_reference_avg_sharess           0.006136         -0.012601
# weekday_is_monday                    0.010440         -0.000777
# weekday_is_tuesday                   0.005820         -0.005587
# weekday_is_wednesday                 0.014873         -0.010843
# weekday_is_thursday                 -0.029619         -0.005218
# weekday_is_friday                   -0.004186         -0.016759
# weekday_is_saturday                  0.003162          0.024057
# weekday_is_sunday                    0.000980          0.035419
# is_weekend                           0.003001          0.043727
# LDA_00                              -0.068836          0.045975
# LDA_01                               0.055859         -0.013028
# LDA_02                               0.046857          0.084404
# LDA_03                               0.044647         -0.141882
# LDA_04                              -0.068596          0.030845
# global_subjectivity                 -0.045368          0.127968
# global_sentiment_polarity           -0.044767          0.021794
# global_rate_positive_words          -0.049924          0.133019
# global_rate_negative_words           0.000029          0.120182
# rate_positive_words                 -0.047907          0.104122
# rate_negative_words                  0.013565          0.096643
# avg_positive_polarity               -0.047737          0.136749
# min_positive_polarity               -0.024666         -0.257418
# max_positive_polarity               -0.024662          0.422986
# avg_negative_polarity               -0.000047         -0.132024
# min_negative_polarity                0.003830         -0.445104
# max_negative_polarity               -0.000152          0.233543
# title_subjectivity                   0.068703         -0.008624
# title_sentiment_polarity             0.008593          0.028859
# abs_title_subjectivity              -0.154435          0.009432
# abs_title_sentiment_polarity         0.031771          0.006166
# shares                              -0.015418          0.019353
#
#                                n_unique_tokens  n_non_stop_words  \
# n_tokens_title                       -0.038403         -0.043665
# n_tokens_content                     -0.406451          0.204110
# n_unique_tokens                       1.000000          0.677414
# n_non_stop_words                      0.677414          1.000000
# n_non_stop_unique_tokens              0.937981          0.764777
# num_hrefs                            -0.121523          0.162961
# num_self_hrefs                       -0.056898          0.144604
# num_imgs                             -0.242216          0.009771
# num_videos                            0.023681          0.022246
# average_token_length                  0.651800          0.945168
# num_keywords                         -0.086237         -0.039689
# data_channel_is_lifestyle            -0.013716          0.032220
# data_channel_is_entertainment         0.000007         -0.012141
# data_channel_is_bus                   0.046108          0.065006
# data_channel_is_socmed                0.008699          0.036689
# data_channel_is_tech                  0.005484          0.075754
# data_channel_is_world                -0.066599          0.006376
# kw_min_min                            0.090242          0.048274
# kw_max_min                           -0.025170         -0.010038
# kw_avg_min                            0.000232          0.014065
# kw_min_max                            0.003937         -0.028634
# kw_max_max                           -0.100938         -0.059095
# kw_avg_max                           -0.046249         -0.168240
# kw_min_avg                           -0.027510         -0.066776
# kw_max_avg                           -0.026168         -0.064821
# kw_avg_avg                           -0.039853         -0.141375
# self_reference_min_shares             0.039078          0.031837
# self_reference_max_shares             0.024997          0.044684
# self_reference_avg_sharess            0.041976          0.043181
# weekday_is_monday                     0.002198          0.002045
# weekday_is_tuesday                    0.001033          0.005645
# weekday_is_wednesday                 -0.004565         -0.017970
# weekday_is_thursday                   0.010294          0.007409
# weekday_is_friday                     0.027286          0.012360
# weekday_is_saturday                  -0.032919          0.000602
# weekday_is_sunday                    -0.020827         -0.013554
# is_weekend                           -0.039183         -0.009696
# LDA_00                                0.028078          0.077309
# LDA_01                                0.053082         -0.002996
# LDA_02                               -0.075972          0.021905
# LDA_03                               -0.001839         -0.183997
# LDA_04                                0.009131          0.096756
# global_subjectivity                   0.489412          0.665645
# global_sentiment_polarity             0.176232          0.216284
# global_rate_positive_words            0.294712          0.398745
# global_rate_negative_words            0.173285          0.266334
# rate_positive_words                   0.441953          0.627997
# rate_negative_words                   0.194845          0.321355
# avg_positive_polarity                 0.426527          0.593781
# min_positive_polarity                 0.408328          0.229293
# max_positive_polarity                 0.156557          0.531191
# avg_negative_polarity                -0.218106         -0.355289
# min_negative_polarity                 0.020527         -0.313846
# max_negative_polarity                -0.335336         -0.198110
# title_subjectivity                    0.013651         -0.013664
# title_sentiment_polarity             -0.039008         -0.020175
# abs_title_subjectivity               -0.000501          0.019464
# abs_title_sentiment_polarity         -0.004249         -0.016578
# shares                               -0.011017         -0.000042
#
#                                n_non_stop_unique_tokens  num_hrefs  \
# n_tokens_title                                -0.042015  -0.065715
# n_tokens_content                              -0.227762   0.444034
# n_unique_tokens                                0.937981  -0.121523
# n_non_stop_words                               0.764777   0.162961
# n_non_stop_unique_tokens                       1.000000  -0.115556
# num_hrefs                                     -0.115556   1.000000
# num_self_hrefs                                -0.028669   0.382373
# num_imgs                                      -0.301335   0.357070
# num_videos                                     0.015197   0.099386
# average_token_length                           0.704762   0.220140
# num_keywords                                  -0.090747   0.127923
# data_channel_is_lifestyle                      0.018489   0.052150
# data_channel_is_entertainment                 -0.009688  -0.003093
# data_channel_is_bus                            0.087437  -0.052802
# data_channel_is_socmed                         0.011165   0.037383
# data_channel_is_tech                           0.031460  -0.070473
# data_channel_is_world                         -0.021753  -0.021443
# kw_min_min                                     0.084927  -0.038750
# kw_max_min                                    -0.026037   0.020918
# kw_avg_min                                     0.002454   0.014398
# kw_min_max                                    -0.011927  -0.010859
# kw_max_max                                    -0.093108   0.042681
# kw_avg_max                                    -0.095166  -0.027312
# kw_min_avg                                    -0.064987   0.067793
# kw_max_avg                                    -0.058342   0.070941
# kw_avg_avg                                    -0.114106   0.119142
# self_reference_min_shares                      0.036663  -0.002263
# self_reference_max_shares                      0.030631   0.065480
# self_reference_avg_sharess                     0.041244   0.023002
# weekday_is_monday                              0.004487  -0.008481
# weekday_is_tuesday                             0.003356  -0.017424
# weekday_is_wednesday                           0.002926  -0.032590
# weekday_is_thursday                            0.004467  -0.015104
# weekday_is_friday                              0.024590   0.002407
# weekday_is_saturday                           -0.026031   0.061089
# weekday_is_sunday                             -0.033283   0.051977
# is_weekend                                    -0.043548   0.082672
# LDA_00                                         0.079624  -0.015594
# LDA_01                                         0.047019  -0.047318
# LDA_02                                        -0.023788  -0.010792
# LDA_03                                        -0.134125   0.124720
# LDA_04                                         0.050675  -0.066108
# global_subjectivity                            0.526344   0.200792
# global_sentiment_polarity                      0.174127   0.091926
# global_rate_positive_words                     0.347323   0.047247
# global_rate_negative_words                     0.218330   0.025990
# rate_positive_words                            0.488194   0.100933
# rate_negative_words                            0.234480   0.055240
# avg_positive_polarity                          0.458646   0.197363
# min_positive_polarity                          0.322758  -0.085490
# max_positive_polarity                          0.269794   0.295327
# avg_negative_polarity                         -0.255956  -0.147799
# min_negative_polarity                         -0.102251  -0.259035
# max_negative_polarity                         -0.267221   0.068974
# title_subjectivity                            -0.010230   0.039773
# title_sentiment_polarity                      -0.043188   0.040287
# abs_title_subjectivity                         0.017453   0.002897
# abs_title_sentiment_polarity                  -0.026725   0.054783
# shares                                        -0.035478   0.072622
#
#                                num_self_hrefs  num_imgs  num_videos  \
# n_tokens_title                      -0.025405 -0.009692    0.044753
# n_tokens_content                     0.321827  0.331687    0.111323
# n_unique_tokens                     -0.056898 -0.242216    0.023681
# n_non_stop_words                     0.144604  0.009771    0.022246
# n_non_stop_unique_tokens            -0.028669 -0.301335    0.015197
# num_hrefs                            0.382373  0.357070    0.099386
# num_self_hrefs                       1.000000  0.238780    0.076983
# num_imgs                             0.238780  1.000000   -0.067125
# num_videos                           0.076983 -0.067125    1.000000
# average_token_length                 0.127390  0.036794   -0.001284
# num_keywords                         0.102849  0.085009   -0.015891
# data_channel_is_lifestyle           -0.045801  0.003693   -0.044708
# data_channel_is_entertainment        0.031508  0.090939    0.135272
# data_channel_is_bus                 -0.054486 -0.139187   -0.068185
# data_channel_is_socmed               0.094435 -0.018377   -0.017104
# data_channel_is_tech                 0.146377  0.005725   -0.103158
# data_channel_is_world               -0.111702 -0.102380   -0.092570
# kw_min_min                          -0.020686 -0.038018    0.008566
# kw_max_min                           0.001524  0.029174   -0.000301
# kw_avg_min                           0.001393  0.009245   -0.013252
# kw_min_max                          -0.013860  0.007957    0.072184
# kw_max_max                           0.004369  0.050672    0.006312
# kw_avg_max                          -0.063541 -0.000719    0.160309
# kw_min_avg                           0.035605  0.093803    0.074925
# kw_max_avg                          -0.025801  0.082900    0.048459
# kw_avg_avg                          -0.023308  0.150852    0.121061
# self_reference_min_shares           -0.026427 -0.002208   -0.013473
# self_reference_max_shares            0.109870  0.030674    0.042572
# self_reference_avg_sharess           0.015684  0.011057    0.012646
# weekday_is_monday                    0.013776 -0.011379    0.003861
# weekday_is_tuesday                  -0.006792 -0.000832    0.010686
# weekday_is_wednesday                -0.018080 -0.027765   -0.009020
# weekday_is_thursday                 -0.021526  0.006433   -0.006295
# weekday_is_friday                   -0.019204 -0.021273    0.018953
# weekday_is_saturday                  0.053500  0.019058   -0.013886
# weekday_is_sunday                    0.027037  0.063419   -0.012147
# is_weekend                           0.058592  0.061061   -0.019040
# LDA_00                              -0.010586 -0.148386   -0.071831
# LDA_01                              -0.005067  0.034285   -0.005339
# LDA_02                              -0.085739 -0.102738   -0.097020
# LDA_03                              -0.021818  0.221068    0.293118
# LDA_04                               0.116665 -0.016294   -0.134126
# global_subjectivity                  0.103866  0.069696    0.084161
# global_sentiment_polarity            0.084261  0.034488   -0.033254
# global_rate_positive_words           0.117329 -0.039331    0.074241
# global_rate_negative_words           0.009546  0.010051    0.189525
# rate_positive_words                  0.139876 -0.010200   -0.047843
# rate_negative_words                 -0.013000  0.023970    0.082446
# avg_positive_polarity                0.090989  0.098633    0.099368
# min_positive_polarity               -0.080557 -0.027758   -0.010119
# max_positive_polarity                0.188458  0.166023    0.124412
# avg_negative_polarity               -0.057174 -0.052124   -0.110872
# min_negative_polarity               -0.127036 -0.118805   -0.136349
# max_negative_polarity                0.045272  0.062627    0.033905
# title_subjectivity                  -0.016506  0.049578    0.067326
# title_sentiment_polarity             0.027262  0.041283    0.027092
# abs_title_subjectivity               0.007066 -0.021999   -0.025826
# abs_title_sentiment_polarity        -0.013638  0.063551    0.056223
# shares                               0.035308  0.090645    0.028749
#
#                                average_token_length  ...  \
# n_tokens_title                            -0.068069  ...
# n_tokens_content                           0.174439  ...
# n_unique_tokens                            0.651800  ...
# n_non_stop_words                           0.945168  ...
# n_non_stop_unique_tokens                   0.704762  ...
# num_hrefs                                  0.220140  ...
# num_self_hrefs                             0.127390  ...
# num_imgs                                   0.036794  ...
# num_videos                                -0.001284  ...
# average_token_length                       1.000000  ...
# num_keywords                              -0.030228  ...
# data_channel_is_lifestyle                  0.016532  ...
# data_channel_is_entertainment             -0.052105  ...
# data_channel_is_bus                        0.071481  ...
# data_channel_is_socmed                     0.027586  ...
# data_channel_is_tech                       0.018159  ...
# data_channel_is_world                      0.089894  ...
# kw_min_min                                 0.039692  ...
# kw_max_min                                -0.007422  ...
# kw_avg_min                                 0.013289  ...
# kw_min_max                                -0.030265  ...
# kw_max_max                                -0.049027  ...
# kw_avg_max                                -0.157141  ...
# kw_min_avg                                -0.071819  ...
# kw_max_avg                                -0.055779  ...
# kw_avg_avg                                -0.136108  ...
# self_reference_min_shares                  0.034622  ...
# self_reference_max_shares                  0.041483  ...
# self_reference_avg_sharess                 0.042208  ...
# weekday_is_monday                          0.004707  ...
# weekday_is_tuesday                         0.004499  ...
# weekday_is_wednesday                      -0.028347  ...
# weekday_is_thursday                        0.010221  ...
# weekday_is_friday                          0.015227  ...
# weekday_is_saturday                       -0.000355  ...
# weekday_is_sunday                         -0.007196  ...
# is_weekend                                -0.005632  ...
# LDA_00                                     0.079914  ...
# LDA_01                                    -0.040625  ...
# LDA_02                                     0.105529  ...
# LDA_03                                    -0.179467  ...
# LDA_04                                     0.038420  ...
# global_subjectivity                        0.598052  ...
# global_sentiment_polarity                  0.178242  ...
# global_rate_positive_words                 0.320539  ...
# global_rate_negative_words                 0.228596  ...
# rate_positive_words                        0.575703  ...
# rate_negative_words                        0.326031  ...
# avg_positive_polarity                      0.543724  ...
# min_positive_polarity                      0.216610  ...
# max_positive_polarity                      0.469316  ...
# avg_negative_polarity                     -0.326674  ...
# min_negative_polarity                     -0.283058  ...
# max_negative_polarity                     -0.190196  ...
# title_subjectivity                        -0.019554  ...
# title_sentiment_polarity                  -0.027699  ...
# abs_title_subjectivity                     0.022401  ...
# abs_title_sentiment_polarity              -0.020841  ...
# shares                                     0.002703  ...
#
#                                min_positive_polarity  max_positive_polarity  \
# n_tokens_title                             -0.024666              -0.024662
# n_tokens_content                           -0.257418               0.422986
# n_unique_tokens                             0.408328               0.156557
# n_non_stop_words                            0.229293               0.531191
# n_non_stop_unique_tokens                    0.322758               0.269794
# num_hrefs                                  -0.085490               0.295327
# num_self_hrefs                             -0.080557               0.188458
# num_imgs                                   -0.027758               0.166023
# num_videos                                 -0.010119               0.124412
# average_token_length                        0.216610               0.469316
# num_keywords                               -0.012402               0.057021
# data_channel_is_lifestyle                  -0.007486               0.064370
# data_channel_is_entertainment              -0.029614               0.074151
# data_channel_is_bus                        -0.039747               0.016447
# data_channel_is_socmed                     -0.064513               0.024491
# data_channel_is_tech                        0.035980               0.030114
# data_channel_is_world                      -0.042505              -0.131630
# kw_min_min                                  0.006302               0.019473
# kw_max_min                                  0.009459               0.020641
# kw_avg_min                                  0.007476               0.030290
# kw_min_max                                  0.003139              -0.005430
# kw_max_max                                 -0.009238              -0.022662
# kw_avg_max                                  0.013015              -0.095879
# kw_min_avg                                  0.018904              -0.003212
# kw_max_avg                                  0.030121               0.010020
# kw_avg_avg                                  0.057157               0.004096
# self_reference_min_shares                   0.029800               0.007860
# self_reference_max_shares                   0.005822               0.048788
# self_reference_avg_sharess                  0.026617               0.027167
# weekday_is_monday                           0.000042               0.002424
# weekday_is_tuesday                         -0.009769              -0.008485
# weekday_is_wednesday                       -0.012324              -0.009393
# weekday_is_thursday                         0.008813              -0.008271
# weekday_is_friday                           0.019196              -0.008333
# weekday_is_saturday                        -0.023132               0.035619
# weekday_is_sunday                           0.015638               0.014559
# is_weekend                                 -0.004914               0.036437
# LDA_00                                     -0.099073               0.051689
# LDA_01                                      0.008741               0.051264
# LDA_02                                     -0.053088              -0.118940
# LDA_03                                      0.101128              -0.006442
# LDA_04                                      0.031704               0.034523
# global_subjectivity                         0.234361               0.510864
# global_sentiment_polarity                   0.100228               0.432029
# global_rate_positive_words                 -0.099408               0.475793
# global_rate_negative_words                  0.053787               0.180701
# rate_positive_words                         0.057160               0.460701
# rate_negative_words                         0.181816               0.020785
# avg_positive_polarity                       0.460922               0.703696
# min_positive_polarity                       1.000000               0.016007
# max_positive_polarity                       0.016007               1.000000
# avg_negative_polarity                      -0.049645              -0.254795
# min_negative_polarity                       0.096664              -0.345425
# max_negative_polarity                      -0.198511               0.000051
# title_subjectivity                          0.033079               0.048353
# title_sentiment_polarity                    0.005936               0.073582
# abs_title_subjectivity                      0.014166              -0.012913
# abs_title_sentiment_polarity                0.039646               0.084061
# shares                                      0.017045               0.006418
#
#                                avg_negative_polarity  min_negative_polarity  \
# n_tokens_title                             -0.000047               0.003830
# n_tokens_content                           -0.132024              -0.445104
# n_unique_tokens                            -0.218106               0.020527
# n_non_stop_words                           -0.355289              -0.313846
# n_non_stop_unique_tokens                   -0.255956              -0.102251
# num_hrefs                                  -0.147799              -0.259035
# num_self_hrefs                             -0.057174              -0.127036
# num_imgs                                   -0.052124              -0.118805
# num_videos                                 -0.110872              -0.136349
# average_token_length                       -0.326674              -0.283058
# num_keywords                                0.030490               0.010232
# data_channel_is_lifestyle                  -0.010083              -0.025354
# data_channel_is_entertainment              -0.100331              -0.093043
# data_channel_is_bus                         0.043045               0.050234
# data_channel_is_socmed                      0.013111               0.000832
# data_channel_is_tech                        0.116785               0.122088
# data_channel_is_world                       0.015819              -0.072101
# kw_min_min                                  0.013054               0.053302
# kw_max_min                                  0.007286               0.015368
# kw_avg_min                                  0.004485               0.016990
# kw_min_max                                 -0.012105              -0.001268
# kw_max_max                                 -0.014379              -0.059122
# kw_avg_max                                 -0.019804               0.006559
# kw_min_avg                                 -0.033118              -0.017390
# kw_max_avg                                 -0.030828              -0.006469
# kw_avg_avg                                 -0.062432              -0.011515
# self_reference_min_shares                  -0.028617              -0.007814
# self_reference_max_shares                  -0.052285              -0.046325
# self_reference_avg_sharess                 -0.047313              -0.026151
# weekday_is_monday                           0.003948               0.007118
# weekday_is_tuesday                          0.014126               0.004133
# weekday_is_wednesday                        0.039334               0.033933
# weekday_is_thursday                        -0.016594              -0.010805
# weekday_is_friday                          -0.023595              -0.007574
# weekday_is_saturday                        -0.015631              -0.026720
# weekday_is_sunday                          -0.014855              -0.016729
# is_weekend                                 -0.022316              -0.031673
# LDA_00                                      0.035583               0.032636
# LDA_01                                     -0.085672              -0.051757
# LDA_02                                      0.023402              -0.075702
# LDA_03                                     -0.106951              -0.025651
# LDA_04                                      0.116883               0.106549
# global_subjectivity                        -0.439632              -0.347775
# global_sentiment_polarity                   0.246130               0.301383
# global_rate_positive_words                 -0.120458              -0.105228
# global_rate_negative_words                 -0.350831              -0.482106
# rate_positive_words                        -0.036516               0.089197
# rate_negative_words                        -0.345215              -0.453089
# avg_positive_polarity                      -0.264103              -0.222468
# min_positive_polarity                      -0.049645               0.096664
# max_positive_polarity                      -0.254795              -0.345425
# avg_negative_polarity                       1.000000               0.751509
# min_negative_polarity                       0.751509               1.000000
# max_negative_polarity                       0.570595               0.071614
# title_subjectivity                         -0.071093              -0.049631
# title_sentiment_polarity                    0.098170               0.093905
# abs_title_subjectivity                     -0.024239              -0.033365
# abs_title_sentiment_polarity               -0.082918              -0.061228
# shares                                     -0.063230              -0.042182
#
#                                max_negative_polarity  title_subjectivity  \
# n_tokens_title                             -0.000152            0.068703
# n_tokens_content                            0.233543           -0.008624
# n_unique_tokens                            -0.335336            0.013651
# n_non_stop_words                           -0.198110           -0.013664
# n_non_stop_unique_tokens                   -0.267221           -0.010230
# num_hrefs                                   0.068974            0.039773
# num_self_hrefs                              0.045272           -0.016506
# num_imgs                                    0.062627            0.049578
# num_videos                                  0.033905            0.067326
# average_token_length                       -0.190196           -0.019554
# num_keywords                                0.039953            0.012406
# data_channel_is_lifestyle                   0.017023            0.002026
# data_channel_is_entertainment               0.001261            0.054804
# data_channel_is_bus                        -0.009468           -0.040747
# data_channel_is_socmed                     -0.001825           -0.019566
# data_channel_is_tech                        0.016733           -0.047339
# data_channel_is_world                       0.063786           -0.056113
# kw_min_min                                 -0.029115           -0.001603
# kw_max_min                                  0.004393            0.031925
# kw_avg_min                                 -0.002436            0.026252
# kw_min_max                                 -0.011210            0.015113
# kw_max_max                                  0.030322            0.002443
# kw_avg_max                                 -0.028858            0.032629
# kw_min_avg                                 -0.018901            0.042618
# kw_max_avg                                 -0.010937            0.054712
# kw_avg_avg                                 -0.041078            0.092418
# self_reference_min_shares                  -0.023593            0.006542
# self_reference_max_shares                  -0.017152            0.004409
# self_reference_avg_sharess                 -0.029618            0.001858
# weekday_is_monday                           0.011705           -0.020971
# weekday_is_tuesday                          0.010209           -0.011655
# weekday_is_wednesday                        0.014747           -0.000960
# weekday_is_thursday                        -0.019695            0.017295
# weekday_is_friday                          -0.028142           -0.009784
# weekday_is_saturday                         0.025642            0.006496
# weekday_is_sunday                          -0.010711            0.032088
# is_weekend                                  0.010397            0.028638
# LDA_00                                     -0.001210           -0.046531
# LDA_01                                     -0.033308            0.056354
# LDA_02                                      0.072565           -0.072749
# LDA_03                                     -0.072081            0.125336
# LDA_04                                      0.029543           -0.056902
# global_subjectivity                        -0.220770            0.121519
# global_sentiment_polarity                  -0.044681            0.026937
# global_rate_positive_words                 -0.076494            0.097422
# global_rate_negative_words                  0.073229            0.091134
# rate_positive_words                        -0.204794           -0.014536
# rate_negative_words                         0.032468            0.004277
# avg_positive_polarity                      -0.144547            0.066074
# min_positive_polarity                      -0.198511            0.033079
# max_positive_polarity                       0.000051            0.048353
# avg_negative_polarity                       0.570595           -0.071093
# min_negative_polarity                       0.071614           -0.049631
# max_negative_polarity                       1.000000           -0.012776
# title_subjectivity                         -0.012776            1.000000
# title_sentiment_polarity                    0.002989            0.248392
# abs_title_subjectivity                      0.003894           -0.478374
# abs_title_sentiment_polarity               -0.016834            0.712599
# shares                                     -0.022182            0.018348
#
#                                title_sentiment_polarity  \
# n_tokens_title                                 0.008593
# n_tokens_content                               0.028859
# n_unique_tokens                               -0.039008
# n_non_stop_words                              -0.020175
# n_non_stop_unique_tokens                      -0.043188
# num_hrefs                                      0.040287
# num_self_hrefs                                 0.027262
# num_imgs                                       0.041283
# num_videos                                     0.027092
# average_token_length                          -0.027699
# num_keywords                                   0.042379
# data_channel_is_lifestyle                      0.044929
# data_channel_is_entertainment                 -0.004769
# data_channel_is_bus                            0.003554
# data_channel_is_socmed                         0.021475
# data_channel_is_tech                           0.021209
# data_channel_is_world                         -0.080088
# kw_min_min                                     0.043383
# kw_max_min                                     0.034400
# kw_avg_min                                     0.030298
# kw_min_max                                     0.006100
# kw_max_max                                    -0.042755
# kw_avg_max                                    -0.019559
# kw_min_avg                                     0.013000
# kw_max_avg                                     0.028630
# kw_avg_avg                                     0.036928
# self_reference_min_shares                     -0.015870
# self_reference_max_shares                     -0.001893
# self_reference_avg_sharess                    -0.012385
# weekday_is_monday                             -0.002316
# weekday_is_tuesday                            -0.004086
# weekday_is_wednesday                          -0.007686
# weekday_is_thursday                           -0.000751
# weekday_is_friday                             -0.018443
# weekday_is_saturday                            0.016009
# weekday_is_sunday                              0.033678
# is_weekend                                     0.036652
# LDA_00                                         0.022874
# LDA_01                                         0.000051
# LDA_02                                        -0.078583
# LDA_03                                         0.027013
# LDA_04                                         0.026630
# global_subjectivity                            0.022354
# global_sentiment_polarity                      0.246909
# global_rate_positive_words                     0.116903
# global_rate_negative_words                    -0.155642
# rate_positive_words                            0.141473
# rate_negative_words                           -0.194053
# avg_positive_polarity                          0.082751
# min_positive_polarity                          0.005936
# max_positive_polarity                          0.073582
# avg_negative_polarity                          0.098170
# min_negative_polarity                          0.093905
# max_negative_polarity                          0.002989
# title_subjectivity                             0.248392
# title_sentiment_polarity                       1.000000
# abs_title_subjectivity                        -0.235973
# abs_title_sentiment_polarity                   0.425893
# shares                                        -0.014473
#
#                                abs_title_subjectivity  \
# n_tokens_title                              -0.154435
# n_tokens_content                             0.009432
# n_unique_tokens                             -0.000501
# n_non_stop_words                             0.019464
# n_non_stop_unique_tokens                     0.017453
# num_hrefs                                    0.002897
# num_self_hrefs                               0.007066
# num_imgs                                    -0.021999
# num_videos                                  -0.025826
# average_token_length                         0.022401
# num_keywords                                -0.004695
# data_channel_is_lifestyle                    0.003466
# data_channel_is_entertainment               -0.061168
# data_channel_is_bus                         -0.003545
# data_channel_is_socmed                       0.012027
# data_channel_is_tech                         0.009266
# data_channel_is_world                        0.056579
# kw_min_min                                   0.014092
# kw_max_min                                  -0.017547
# kw_avg_min                                  -0.012708
# kw_min_max                                   0.000686
# kw_max_max                                  -0.012822
# kw_avg_max                                  -0.010922
# kw_min_avg                                  -0.008634
# kw_max_avg                                  -0.012821
# kw_avg_avg                                  -0.020247
# self_reference_min_shares                    0.002622
# self_reference_max_shares                    0.005842
# self_reference_avg_sharess                   0.005382
# weekday_is_monday                            0.004673
# weekday_is_tuesday                           0.022118
# weekday_is_wednesday                        -0.005364
# weekday_is_thursday                         -0.002291
# weekday_is_friday                            0.008306
# weekday_is_saturday                         -0.020399
# weekday_is_sunday                           -0.021760
# is_weekend                                  -0.030896
# LDA_00                                      -0.004872
# LDA_01                                      -0.073417
# LDA_02                                       0.056002
# LDA_03                                      -0.006144
# LDA_04                                       0.011953
# global_subjectivity                         -0.003342
# global_sentiment_polarity                   -0.039223
# global_rate_positive_words                  -0.131002
# global_rate_negative_words                  -0.046488
# rate_positive_words                         -0.023503
# rate_negative_words                          0.048486
# avg_positive_polarity                        0.012472
# min_positive_polarity                        0.014166
# max_positive_polarity                       -0.012913
# avg_negative_polarity                       -0.024239
# min_negative_polarity                       -0.033365
# max_negative_polarity                        0.003894
# title_subjectivity                          -0.478374
# title_sentiment_polarity                    -0.235973
# abs_title_subjectivity                       1.000000
# abs_title_sentiment_polarity                -0.393374
# shares                                      -0.000489
#
#                                abs_title_sentiment_polarity    shares
# n_tokens_title                                     0.031771 -0.015418
# n_tokens_content                                   0.006166  0.019353
# n_unique_tokens                                   -0.004249 -0.011017
# n_non_stop_words                                  -0.016578 -0.000042
# n_non_stop_unique_tokens                          -0.026725 -0.035478
# num_hrefs                                          0.054783  0.072622
# num_self_hrefs                                    -0.013638  0.035308
# num_imgs                                           0.063551  0.090645
# num_videos                                         0.056223  0.028749
# average_token_length                              -0.020841  0.002703
# num_keywords                                       0.035257 -0.009732
# data_channel_is_lifestyle                          0.008507  0.002742
# data_channel_is_entertainment                      0.044129  0.008710
# data_channel_is_bus                               -0.035203 -0.022866
# data_channel_is_socmed                            -0.002541  0.005794
# data_channel_is_tech                              -0.042337 -0.019705
# data_channel_is_world                             -0.071935 -0.044712
# kw_min_min                                         0.010202  0.018588
# kw_max_min                                         0.035700  0.041228
# kw_avg_min                                         0.023465  0.034295
# kw_min_max                                         0.005378  0.037648
# kw_max_max                                        -0.012244 -0.008245
# kw_avg_max                                         0.018475  0.023130
# kw_min_avg                                         0.042619  0.077779
# kw_max_avg                                         0.071589  0.079531
# kw_avg_avg                                         0.102418  0.107429
# self_reference_min_shares                          0.007906  0.023078
# self_reference_max_shares                          0.006703  0.028921
# self_reference_avg_sharess                         0.004413  0.029220
# weekday_is_monday                                 -0.020122  0.009373
# weekday_is_tuesday                                -0.009560 -0.011826
# weekday_is_wednesday                              -0.005336  0.000381
# weekday_is_thursday                                0.013429 -0.012769
# weekday_is_friday                                 -0.016659 -0.000629
# weekday_is_saturday                                0.010304  0.003460
# weekday_is_sunday                                  0.046414  0.021041
# is_weekend                                         0.042074  0.018204
# LDA_00                                            -0.035937 -0.014762
# LDA_01                                             0.042658  0.011302
# LDA_02                                            -0.088763 -0.055645
# LDA_03                                             0.132007  0.075461
# LDA_04                                            -0.047843 -0.018215
# global_subjectivity                                0.103776  0.064016
# global_sentiment_polarity                          0.069562 -0.037820
# global_rate_positive_words                         0.088709  0.004370
# global_rate_negative_words                         0.064529  0.037965
# rate_positive_words                               -0.001157 -0.022858
# rate_negative_words                               -0.015502  0.028205
# avg_positive_polarity                              0.117517  0.028890
# min_positive_polarity                              0.039646  0.017045
# max_positive_polarity                              0.084061  0.006418
# avg_negative_polarity                             -0.082918 -0.063230
# min_negative_polarity                             -0.061228 -0.042182
# max_negative_polarity                             -0.016834 -0.022182
# title_subjectivity                                 0.712599  0.018348
# title_sentiment_polarity                           0.425893 -0.014473
# abs_title_subjectivity                            -0.393374 -0.000489
# abs_title_sentiment_polarity                       1.000000  0.047195
# shares                                             0.047195  1.000000
#
# [59 rows x 59 columns]

# %%
from sklearn.model_selection import train_test_split
X= train.drop('shares',axis=1)
y=train['shares']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error

clf = ExtraTreesRegressor()
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print(mean_absolute_error(y_test, y_pred))
# Out:
# 8119.792025219717

# %%
output = clf.predict(test)

# %%
output = pd.DataFrame(output)
output = output.astype(int)
output.to_csv('output-1.csv',index=False)

# %%
output
# Out:
#            0
# 0      20620
# 1       7389
# 2       7018
# 3       2584
# 4       3100
# ...      ...
# 31711   8369
# 31712   5973
# 31713   5834
# 31714   7320
# 31715   7209
#
# [31716 rows x 1 columns]
